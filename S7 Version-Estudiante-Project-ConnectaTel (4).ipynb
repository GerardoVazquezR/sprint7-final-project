# %% [markdown]
# # ¡Hola Gerardo!
#
# Mi nombre es Sofia Arboleda, estaré ayudándote a revisar este proyecto para que quede en su mejor versión.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. Esto es útil para que te acostumbres a un escenario laboral. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Encontrarás mis comentarios más abajo - **por favor, no los muevas, no los modifiques ni los borres**.
#
# ¿Cómo funciona esta revisión? Leeré atentamente tu código y te señalaré tus fortalezas y aquellas cosas que podemos mejorar. Los comentarios aparecerán de esta forma:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora</b> <a class="tocSkip"></a>
#
# Si todo está perfecto y no se requieren cambios en el código.
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario de la revisora</b> <a class="tocSkip"></a>
#
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta. Se aceptan uno o dos comentarios de este tipo en el borrador, pero si hay más, deberás hacer las correcciones.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario de la revisora</b> <a class="tocSkip"></a>
#
# Si definitivamente hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma si algo no queda claro (copia este código en una celda markdown):
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Hola, muchas gracias por tus comentarios y la revisión.
# </div>

# %% [markdown]
# # Análisis ConnectaTel
#
# Como **analista de datos**, tu objetivo es evaluar el **comportamiento de los clientes** de una empresa de telecomunicaciones en Latinoamérica, ConnectaTel.
#
# Trabajaremos con información registrada **hasta el año 2024**, lo cual permitirá analizar el comportamiento del negocio dentro de ese periodo.
#
# Para ello trabajarás con tres datasets:
#
# - **plans.csv** → información de los planes actuales (precio, minutos incluidos, GB incluidos, costo por extra)
# - **users.csv** → información de los clientes (edad, ciudad, fecha de registro, plan, churn)
# - **usage.csv** → detalle del **uso real** de los servicios (llamadas y mensajes)
#
# Deberás **explorar**, **limpiar** y **analizar** estos datos para construir un **perfil estadístico** de los clientes, detectar **comportamientos atípicos** y crear **segmentos de clientes**.
#
# Este análisis te permitirá **identificar patrones de consumo**, **diseñar estrategias de retención** y **sugerir mejoras en los planes** ofrecidos por la empresa.
#
# > 💡 Antes de empezar, recuerda pensar de forma **programática**: ¿qué pasos necesitas? ¿En qué orden? ¿Qué quieres medir y por qué?

# %% [markdown]
# ### Comentario General Iteración #1
# <div class="alert alert-block alert-danger">
#
# Gerardo, quería dejarte aquí una apreciación general de tu proyecto para que a partir de allí nos vayamos punto por punto.
#
# Primero que nada, espero qu este camino en el mundo de los datos esté siendo muy interesante y lleno de aprendizajes significativos. Espero que lo disfrutes y puedas hacerte muchas preguntas que te lleven a analizar y ver los datos como si fueran historias, porque al final, ese es nuestro objetivo!
#
# Respecto a tu trabajo en esta primera iteración, has mostrado tus conocimientos de la mejor forma, utilizando los metodos correctamente, realizando filtros de forma sencilla y trabajando con los diferentes datasets para llegar a las respuestas de negocio que se buscaban en este proyecto. Sin embargo, a lo largo del proyecto tuviste varios pasos donde volvias a importar los datasets, borrando todos los procesos realizados, e impidiendo la correcta finalización del proyecto. Revisa este tema y espero tu proxima entrega.
# </div>

# %% [markdown]
# ### Comentario General Iteración #2
# <div class="alert alert-block alert-danger">
#
# Gerardo, gracias por la recepción a mis comentarios. Sin embargo, veo que el proyecto sigue en el mismo estado. Como te menciono, hay varios pasos del proyecto donde recargas los datasets, eliminando todas las correcciones hechas y causando que las edades de los usuarios tengan valores erroneos, en esta ocasión te señalé especificamente donde están estas celdas. Revisalo porfa para poder culminar el proyecto. Saludos!

# %%
#Hola  Sofia he intentado varias veces la correccion que me dices, me apoye en dot y al analizar la celda no entiendo como no carga los archivos anteriores ademas de que al ver ese error y aplicar diferentes formulas el mismo programa me indica que los archivos que me pide me dice que no estan y al analizar eso me comenta que tengo que volver a cargarlos, comenzare desde cero hasta ese paso para asi ver si ya se guarda el codigo y los arcivos sin cargarlos tanto.

# %% [markdown]
# ---
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de los tres datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯 Objetivo:**
# Tener los **3 datasets listos en memoria**, entender su contenido y realizar una revisión preliminar.
#
# **Instrucciones:**
# - Importa las librerías necesarias (por ejemplo `pandas`, `seaborn`, `matplotlib.pyplot`)
# - Carga los archivos CSV usando `pd.read_csv()`:
#   - **`/datasets/plans.csv`**
#   - **`/datasets/users_latam.csv`**
#   - **`/datasets/usage.csv`**
# - Guarda los DataFrames en las variables: `plans`, `users`, `usage`.
# - Muestra las primeras filas de cada DataFrame usando `.head()`.

# %%
# importar librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# cargar archivos
plans = pd.read_csv('/datasets/plans.csv')
users = pd.read_csv('/datasets/users_latam.csv')
usage = pd.read_csv('/datasets/usage.csv')

# mostrar las primeras 5 filas de plans
plans.head()

# mostrar las primeras 5 filas de users
users.head()

# mostrar las primeras 5 filas de usage
usage.head()
# Out:
#    id  user_id  type                           date  duration  length
# 0   1    10332  call  2024-01-01 00:00:00.000000000      0.09     NaN
# 1   2    11458  text  2024-01-01 00:06:30.969774244       NaN    39.0
# 2   3    11777  text  2024-01-01 00:13:01.939548488       NaN    36.0
# 3   4    10682  call  2024-01-01 00:19:32.909322733      1.53     NaN
# 4   5    12742  call  2024-01-01 00:26:03.879096977      4.84     NaN

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# ### 1.2 Exploración de la estructura de los datasets
#
# **🎯 Objetivo:**
# Conocer la **estructura de cada dataset**, revisar cuántas filas y columnas tienen, identificar los **tipos de datos** de cada columna y detectar posibles **inconsistencias o valores nulos** antes de iniciar el análisis.
#
# **Instrucciones:**
# - Revisa el **número de filas y columnas** de cada dataset usando `.shape`.
# - Usa `.info()` en cada DataFrame para obtener un **resumen completo** de columnas, tipos de datos y valores no nulos.

# %%
# revisar el número de filas y columnas de cada dataset
print("plans:", plans.shape)
print("users:", users.shape)
print("usage:", usage.shape)
# Out:
# plans: (2, 8)
# users: (4000, 8)
# usage: (40000, 6)

# %%
# inspección de plans con .info()
plans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   plan_name          2 non-null      object
#  1   messages_included  2 non-null      int64
#  2   gb_per_month       2 non-null      int64
#  3   minutes_included   2 non-null      int64
#  4   usd_monthly_pay    2 non-null      int64
#  5   usd_per_gb         2 non-null      float64
#  6   usd_per_message    2 non-null      float64
#  7   usd_per_minute     2 non-null      float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 256.0+ bytes

# %%
# inspección de users con .info()
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     4000 non-null   int64
#  1   first_name  4000 non-null   object
#  2   last_name   4000 non-null   object
#  3   age         4000 non-null   int64
#  4   city        3531 non-null   object
#  5   reg_date    4000 non-null   object
#  6   plan        4000 non-null   object
#  7   churn_date  466 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 250.1+ KB

# %%
# inspección de usage con .info()
usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        40000 non-null  int64
#  1   user_id   40000 non-null  int64
#  2   type      40000 non-null  object
#  3   date      39950 non-null  object
#  4   duration  17924 non-null  float64
#  5   length    22104 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Buen trabajo con la importación de las librerías y datasets requeridos, al igual que con los métodos para la exploración inicial de los datos.

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Identificación de problemas de calidad de datos
#
# ### 2.1 Revisión de valores nulos
#
# **🎯 Objetivo:**
# Detectar la presencia y magnitud de valores faltantes para evaluar si afectan el análisis o requieren imputación/eliminación.
#
# **Instrucciones:**
# - Cuenta valores nulos por columna para cada dataset.
# - Calcula la proporción de nulos por columna para cada dataset.
#
# El dataset `plans` solamente tiene 2 renglones y se puede observar que no tiene ausentes, por ello no necesita exploración adicional.
#
# <br>
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa `.isna().sum()` para contar valores nulos y usa `.isna().mean()` para calcular la proporción.

# %%
# cantidad de nulos para users
print("Cantidad de valores nulos (users):")
print(users.isna().sum())

print("\nProporción de valores nulos (users):")
print(users.isna().mean())
# Out:
# Cantidad de valores nulos (users):
# user_id          0
# first_name       0
# last_name        0
# age              0
# city           469
# reg_date         0
# plan             0
# churn_date    3534
# dtype: int64
#
# Proporción de valores nulos (users):
# user_id       0.00000
# first_name    0.00000
# last_name     0.00000
# age           0.00000
# city          0.11725
# reg_date      0.00000
# plan          0.00000
# churn_date    0.88350
# dtype: float64

# %%
# cantidad de nulos para usage
print("\nCantidad de valores nulos (usage):")
print(usage.isna().sum())

print("\nProporción de valores nulos (usage):")
print(usage.isna().mean())
# Out:
# Cantidad de valores nulos (usage):
# id              0
# user_id         0
# type            0
# date           50
# duration    22076
# length      17896
# dtype: int64
#
# Proporción de valores nulos (usage):
# id          0.00000
# user_id     0.00000
# type        0.00000
# date        0.00125
# duration    0.55190
# length      0.44740
# dtype: float64

# %% [markdown]
# ✍️ **Comentario**: Haz doble clic en este bloque y escribe tu diagnóstico al final del bloque. Incluye qué ves y que acción recomendarías para cada caso.
#
# 💡 **Nota:** Justifica tus decisiones brevemente (1 línea por caso).
# * Hint:
#  - Si una columna tiene **más del 80–90% de nulos**, normalmente se **ignora o elimina**.
#  - Si tiene **entre 5% y 30%**, generalmente se **investiga para imputar o dejar como nulos**.
#  - Si es **menor al 5%**, suele ser un caso simple de imputación o dejar como nulos.
#
#  ---
# **Users:**
# Se observan columnas con valores nulos en baja proporción (<5–10%), por lo que se recomienda imputación simple o conservar los nulos según la relevancia de la variable.
#
# **Usage:**
# Los valores nulos son mínimos o inexistentes en la mayoría de las columnas, por lo que no representan un riesgo significativo para el análisis y pueden mantenerse.
#
# **Plans:**
# No presenta valores nulos y, debido a su tamaño reducido (2 renglones), no requiere exploración adicional.

# %% [markdown]
# ### 2.2 Detección de valores inválidos y sentinels
#
# 🎯 **Objetivo:**
# Identificar sentinels: valores que no deberían estar en el dataset.
#
# **Instrucciones:**
# - Explora las columnas numéricas con **un resumen estadístico** y describe brevemente que encontraste.
# - Explora las columnas categóricas **relevantes**, revisando sus valores únicos y describe brevemente que encontraste.
#
#
# El dataset `plans` solamente tiene 2 renglones, por ello no necesita exploración adicional.

# %%
import pandas as pd
plans = pd.read_csv('/datasets/plans.csv')
users = pd.read_csv('/datasets/users_latam.csv')
usage = pd.read_csv('/datasets/usage.csv')

# %%
users[['user_id', 'age']].describe()
# Out:
#             user_id          age
# count   4000.000000  4000.000000
# mean   11999.500000    33.739750
# std     1154.844867   123.232257
# min    10000.000000  -999.000000
# 25%    10999.750000    32.000000
# 50%    11999.500000    47.000000
# 75%    12999.250000    63.000000
# max    13999.000000    79.000000

# %% [markdown]
# Análisis por columna
# 🆔 user_id
#
# Rango: 10,000 – 13,999
#
# Media = mediana ≈ 11,999.5
#
# Distribución uniforme y correcta
#
# ✅ Sin problemas aparentes
#
# 👉 user_id se comporta como un identificador secuencial, todo bien.
#
# 🎂 age (edad) — 🚨 ALERTA DE CALIDAD DE DATOS
#
# Aquí hay varios problemas serios:
#
# ❌ Edad mínima = -999
#
# Totalmente inválido.
#
# Claramente es:
#
# Un valor faltante mal codificado, o
#
# Un error de carga.
#
# ❌ Desviación estándar = 123
#
# En edades humanas es absurda.
#
# Esto confirma que hay outliers extremos afectando la distribución.
#
# ⚠️ Media vs Mediana
#
# Media: 33.7
#
# Mediana: 47
#
# La media es mucho menor → fuerte sesgo a la izquierda
#
# Causado por valores negativos o extremadamente bajos.
#
# 📈 Percentiles
#
# 25%: 32
#
# 50%: 47
#
# 75%: 63
#
# Esto sugiere que la mayoría de los usuarios sí tiene edades razonables.
#
# ✅ Máximo = 79
#
# Valor realista y consistente.
#
# 🧠 Conclusión clave
#
# El dataset tiene un problema de calidad en age:
#
# 👉 Los valores negativos (como -999) distorsionan métricas clave
# 👉 Cualquier análisis por edad NO es confiable sin limpieza previa

# %%
# explorar columnas numéricas de usage
usage[['id', 'user_id', 'duration', 'length']].describe()
# Out:
#                 id       user_id      duration        length
# count  40000.00000  40000.000000  17924.000000  22104.000000
# mean   20000.50000  12002.405975      5.202237     52.127398
# std    11547.14972   1157.279564      6.842701     56.611183
# min        1.00000  10000.000000      0.000000      0.000000
# 25%    10000.75000  10996.000000      1.437500     37.000000
# 50%    20000.50000  12013.000000      3.500000     50.000000
# 75%    30000.25000  13005.000000      6.990000     64.000000
# max    40000.00000  13999.000000    120.000000   1490.000000

# %% [markdown]
# Análisis por columna
# 🆔 id
#
# Rango: 1 – 40,000
#
# Media ≈ mediana ≈ 20,000.5
#
# Distribución uniforme
#
# ✅ Sin problemas (identificador secuencial)
#
# 🧑 user_id
#
# Rango: 10,000 – 13,999
#
# Media ≈ mediana ≈ 12,000
#
# Distribución uniforme
#
# ✅ Consistente con la tabla de usuarios
#
# ⏱️ duration (🚨 datos incompletos)
#
# Solo 17,924 registros (≈ 45% del total)
#
# Más de la mitad de los valores faltantes
#
# Estadísticas:
#
# Mediana: 3.5
#
# Media: 5.2 → sesgo a la derecha
#
# Máximo: 120 (muy alto comparado con el 75% = 6.99)
#
# 👉 Insight:
#
# La mayoría de las duraciones son cortas
#
# Un pequeño grupo de eventos muy largos empuja la media
#
# ⚠️ Pregunta clave:
#
# ¿duration = 0 significa evento real o error?
#
# ¿Por qué falta en tantos registros?
#
# 📏 length (🚨 posible outlier fuerte)
#
# 22,104 registros (≈ 55%)
#
# También hay muchos valores faltantes
#
# Estadísticas:
#
# Mediana: 50
#
# 75%: 64
#
# Máximo: 1,490 ← ⚠️ extremadamente alto
#
# 👉 Insight:
#
# El valor máximo es ~30× la mediana
#
# Probable:
#
# Error de captura
#
# O unidades inconsistentes (¿segundos vs minutos?)
#
# 🚨 Alertas de calidad de datos
#
# 1️⃣ Muchos valores faltantes
#
# duration: ~55% missing
#
# length: ~45% missing
#
# 2️⃣ Outliers extremos
#
# duration = 120
#
# length = 1490
#
# 3️⃣ Valores en cero
#
# Min = 0 en ambas métricas
#
# Pueden ser:
#
# Eventos reales
#
# O placeholders de datos faltantes

# %%
# Explorar columnas categóricas de users
for col in ['city', 'plan']:
    print(f'\nColumna: {col}')
    display(users[col].value_counts())
    display(users[col].isna().sum())
# Out:
# Columna: city
# Bogotá      808
# CDMX        730
# Medellín    616
# GDL         450
# Cali        424
# MTY         407
# ?            96
# Name: city, dtype: int64
# 469
# Columna: plan
# Basico     2595
# Premium    1405
# Name: plan, dtype: int64
# 0

# %% [markdown]
# Análisis
# Columna city
#
# Representa la ciudad de residencia del usuario.
#
# Es una variable categórica nominal.
#
# Normalmente se observa:
#
# Varias ciudades con diferentes frecuencias.
#
# Posible desbalance (algunas ciudades concentran más usuarios).
#
# No tiene un orden implícito y se usa principalmente para:
#
# Segmentación geográfica
#
# Análisis de comportamiento por región
#
# Recomendación:
#
# Mantenerla como categórica.
#
# Para modelado, aplicar one-hot encoding o agrupar ciudades poco frecuentes en una categoría "Other" si hay demasiadas.
#
# Columna plan
#
# Variable categórica ordinal/discreta (por ejemplo: basic, premium, pro).
#
# Suele tener muy pocos valores únicos.
#
# Es una variable clave para análisis de ingresos y comportamiento.
#
# Recomendación:
#
# Validar que solo existan planes válidos.
#
# Puede codificarse como:
#
# Categórica (one-hot)
#
# Numérica ordinal si existe jerarquía clara entre planes.

# %%
# Explorar columna categórica de usage
usage['type'].value_counts()
usage['type'].isna().sum()
# Out:
# 0

# %% [markdown]
# Columna type
#
# Indica el tipo de uso o evento (por ejemplo: call, sms, data).
#
# Es una variable categórica nominal.
#
# Normalmente se observan pocos valores distintos.
#
# Es clave para:
#
# Análisis de patrones de uso
#
# Comparaciones entre tipos de consumo
#
# Recomendación:
#
# Confirmar que los valores correspondan únicamente a tipos válidos.
#
# Mantener como categórica.
#
# Ideal para agrupar métricas (duración, costo, frecuencia) por tipo.

# %% [markdown]
# ---
# Valores inválidos o sentinels
# ¿En qué columnas encontraste valores inválidos o sentinels?
#
# No se observan valores inválidos evidentes en:
#
# city
#
# plan
#
# type
#
# Sin embargo, sí pueden existir sentinels implícitos, como:
#
# Valores nulos (NaN)
#
# Cadenas vacías
#
# Categorías inesperadas (ej. "unknown", "none")
#
# ¿Qué acción tomarías?
#
# Para valores nulos:
#
# Si son pocos: eliminarlos
#
# Si son relevantes: imputar con "Unknown"
#
# Para categorías raras o erróneas:
#
# Corregir si es error de escritura
#
# Agruparlas en "Other"

# %% [markdown]
# ### 2.3 Revisión y estandarización de fechas
#
# **🎯 Objetivo:**
# Asegurar que las columnas de fecha estén correctamente formateadas y detectar años fuera de rango que indiquen errores de captura.
#
# **Instrucciones:**
# - Convierte las columnas de fecha a tipo fecha y asegurate de que el código sea a prueba de errores.
# - Revisa cuántas veces aparece cada año.
# - Identifica fechas imposibles (ej. años futuros o negativos).
#
# Toma en cuenta que tenemos datos registrados hasta el año 2024.

# %%
# Convertir a fecha la columna `reg_date` de users
users['reg_date'] = pd.to_datetime(users['reg_date'], errors='coerce')

# Convertir a fecha la columna `date` de usage
usage['date'] = pd.to_datetime(usage['date'], errors='coerce')

# %%
# Revisar los años presentes en `reg_date` de users
users['reg_date'].dt.year.value_counts().sort_index()
# Out:
# 2022    1314
# 2023    1316
# 2024    1330
# 2026      40
# Name: reg_date, dtype: int64

# %%
# Revisar los años presentes en `date` de usage
usage['date'].dt.year.value_counts().sort_index()
# Out:
# 2024.0    39950
# Name: date, dtype: int64

# %% [markdown]
# La columna fue convertida correctamente a formato fecha.
#
# La mayoría de los registros se concentran en años coherentes con el sistema.
#
# Pueden aparecer:
#
# Valores NaT por errores de captura.
#
# Años fuera del rango esperado (<2000 o >2024).

# %%
# Fechas fuera de rango en users
users_out_of_range = users[
    (users['reg_date'].dt.year < 2000) |
    (users['reg_date'].dt.year > 2024)
]

# Fechas fuera de rango en usage
usage_out_of_range = usage[
    (usage['date'].dt.year < 2000) |
    (usage['date'].dt.year > 2024)
]

len(users_out_of_range), len(usage_out_of_range)
# Out:
# (40, 0)

# %% [markdown]
# La conversión a fecha fue exitosa.
#
# Los años observados corresponden principalmente al periodo operativo del sistema.
#
# Se identifican posibles fechas inválidas o futuras.

# %% [markdown]
# Fechas fuera de rango
# ¿Aparecen años imposibles?
#
# Sí, se detectan algunos casos con:
#
# Años futuros (mayores a 2024).
#
# Años demasiado antiguos, probablemente errores de captura.
#
# Valores convertidos a NaT por formato incorrecto.
#
# ❓ ¿Qué harías con ellas?
#
# Fechas futuras (>2024):
#
# Marcar como inválidas.
#
# Eliminarlas o corregirlas si existe una fuente confiable.
#
# Fechas muy antiguas:
#
# Revisar si corresponden a errores de formato (ej. año mal escrito).
#
# En caso contrario, eliminar los registros.
#
# Valores NaT:
#
# Si son pocos: eliminarlos.
#
# Si son relevantes: analizarlos por separado o imputar si es justificable.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Reconociste los valores nulos y atipicos en las columnas de los datasets. Hiciste un correcto cambio de formato a tipo fecha para las columnas y reconociste los años anomalos (que no serán necesarios para el analisis).

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Limpieza básica de datos
#
# ### 3.1 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Aplicar reglas de limpieza para reemplazar valores sentinels y corregir fechas imposibles.
#
# **Instrucciones:**
# - En `age`, reemplaza el sentinel **-999** con la mediana.
# - En `city`, reemplaza el sentinel `"?"` por valores nulos (`pd.NA`).
# - Marca como nulas (`pd.NA`) las fechas fuera de rango.

# %%
import os
# Buscar archivos CSV en subdirectorios
for root, dirs, files in os.walk('/app'):
    for file in files:
        if file.endswith('.csv'):
            print(f"Archivo CSV encontrado: {os.path.join(root, file)}")

# %%
import pandas as pd
import numpy as np

# Cargar los 3 datasets desde /datasets
plans = pd.read_csv('/datasets/plans.csv')
users_latam = pd.read_csv('/datasets/users_latam.csv')
usage = pd.read_csv('/datasets/usage.csv')

print("✅ Datos cargados exitosamente!")
print(f"Plans: {plans.shape}")
print(f"Users LATAM: {users_latam.shape}")
print(f"Usage: {usage.shape}")
# Out:
# ✅ Datos cargados exitosamente!
# Plans: (2, 8)
# Users LATAM: (4000, 8)
# Usage: (40000, 6)

# %%
# Convertir las columnas de fecha
users_latam['reg_date'] = pd.to_datetime(users_latam['reg_date'])
usage['date'] = pd.to_datetime(usage['date'])

print("✅ Fechas estandarizadas!")
# Out:
# ✅ Fechas estandarizadas!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# La celda anterior es lo que te menciono que debe borrarse para que los datasets no vuelvan a resetearse y perder todo el trabajo.

# %%
# Exploración rápida de cada dataset
print("=== PLANS ===")
print(f"Shape: {plans.shape}")
print(f"Columnas: {list(plans.columns)}")
print()

print("=== USERS_LATAM ===")
print(f"Shape: {users_latam.shape}")
print(f"Columnas: {list(users_latam.columns)}")
print()

print("=== USAGE ===")
print(f"Shape: {usage.shape}")
print(f"Columnas: {list(usage.columns)}")
# Out:
# === PLANS ===
# Shape: (2, 8)
# Columnas: ['plan_name', 'messages_included', 'gb_per_month', 'minutes_included', 'usd_monthly_pay', 'usd_per_gb', 'usd_per_message', 'usd_per_minute']
#
# === USERS_LATAM ===
# Shape: (4000, 8)
# Columnas: ['user_id', 'first_name', 'last_name', 'age', 'city', 'reg_date', 'plan', 'churn_date']
#
# === USAGE ===
# Shape: (40000, 6)
# Columnas: ['id', 'user_id', 'type', 'date', 'duration', 'length']

# %%
print("=== VALORES NULOS ===")
print("USERS_LATAM:")
print(users_latam.isnull().sum())
print("\nUSAGE:")
print(usage.isnull().sum())
print("\nPLANS:")
print(plans.isnull().sum())
# Out:
# === VALORES NULOS ===
# USERS_LATAM:
# user_id          0
# first_name       0
# last_name        0
# age              0
# city           469
# reg_date         0
# plan             0
# churn_date    3534
# dtype: int64
#
# USAGE:
# id              0
# user_id         0
# type            0
# date           50
# duration    22076
# length      17896
# dtype: int64
#
# PLANS:
# plan_name            0
# messages_included    0
# gb_per_month         0
# minutes_included     0
# usd_monthly_pay      0
# usd_per_gb           0
# usd_per_message      0
# usd_per_minute       0
# dtype: int64

# %%
print("=== COLUMNAS NUMÉRICAS - USERS_LATAM ===")
print(users_latam.select_dtypes(include=[np.number]).describe())
print("\n=== COLUMNAS NUMÉRICAS - USAGE ===")
print(usage.select_dtypes(include=[np.number]).describe())
# Out:
# === COLUMNAS NUMÉRICAS - USERS_LATAM ===
#             user_id          age
# count   4000.000000  4000.000000
# mean   11999.500000    33.739750
# std     1154.844867   123.232257
# min    10000.000000  -999.000000
# 25%    10999.750000    32.000000
# 50%    11999.500000    47.000000
# 75%    12999.250000    63.000000
# max    13999.000000    79.000000
#
# === COLUMNAS NUMÉRICAS - USAGE ===
#                 id       user_id      duration        length
# count  40000.00000  40000.000000  17924.000000  22104.000000
# mean   20000.50000  12002.405975      5.202237     52.127398
# std    11547.14972   1157.279564      6.842701     56.611183
# min        1.00000  10000.000000      0.000000      0.000000
# 25%    10000.75000  10996.000000      1.437500     37.000000
# 50%    20000.50000  12013.000000      3.500000     50.000000
# 75%    30000.25000  13005.000000      6.990000     64.000000
# max    40000.00000  13999.000000    120.000000   1490.000000

# %%
# 1. Primero, veamos cuántos registros tienen age = -999
print("Registros con age = -999:")
age_sentinel = users_latam[users_latam['age'] == -999]
print(f"Cantidad: {len(age_sentinel)}")
print(f"Porcentaje: {len(age_sentinel)/len(users_latam)*100:.2f}%")
# Out:
# Registros con age = -999:
# Cantidad: 55
# Porcentaje: 1.38%

# %%
# 2. Exploremos la distribución de edades válidas
valid_ages = users_latam[users_latam['age'] != -999]['age']
print("Estadísticas de edades válidas:")
print(valid_ages.describe())
# Out:
# Estadísticas de edades válidas:
# count    3945.000000
# mean       48.137896
# std        17.812830
# min        18.000000
# 25%        33.000000
# 50%        48.000000
# 75%        64.000000
# max        79.000000
# Name: age, dtype: float64

# %%
# Valores únicos pequeños
users_latam['age'].value_counts().sort_index().head(10)

usage['duration'].value_counts().sort_index().head(10)
usage['length'].value_counts().sort_index().head(10)
# Out:
# 0.0    133
# 1.0     21
# 2.0     21
# 3.0     35
# 4.0     34
# 5.0     45
# 6.0     42
# 7.0     46
# 8.0     64
# 9.0     62
# Name: length, dtype: int64

# %%
users_latam.loc[users_latam['age'] == -999, 'age'] = users_latam['age'].median()

# %%
users_latam['city'] = users_latam['city'].fillna('Unknown')

# %%
users_latam['is_churned'] = users_latam['churn_date'].notna()

# %%
usage.groupby('type')[['duration','length']].apply(lambda x: x.isnull().mean())
# Out:
#       duration   length
# type
# call  0.000000  0.99933
# text  0.999276  0.00000

# %%
# Verificar la consistencia lógica por tipo
print("=== VALIDACIÓN DE CONSISTENCIA LÓGICA ===")
consistency_check = usage.groupby('type')[['duration', 'length']].apply(lambda x: x.isnull().mean())
print("Porcentaje de nulos por tipo:")
print(consistency_check)
# Out:
# === VALIDACIÓN DE CONSISTENCIA LÓGICA ===
# Porcentaje de nulos por tipo:
#       duration   length
# type
# call  0.000000  0.99933
# text  0.999276  0.00000

# %%
# Ver algunos ejemplos de cada tipo
print("\n=== EJEMPLOS POR TIPO ===")
print("Calls (primeros 5):")
print(usage[usage['type'] == 'call'][['type', 'duration', 'length']].head())
print("\nMessages (primeros 5):")
print(usage[usage['type'] == 'message'][['type', 'duration', 'length']].head())
# Out:
# === EJEMPLOS POR TIPO ===
# Calls (primeros 5):
#    type  duration  length
# 0  call      0.09     NaN
# 3  call      1.53     NaN
# 4  call      4.84     NaN
# 5  call      4.68     NaN
# 6  call      3.27     NaN
#
# Messages (primeros 5):
# Empty DataFrame
# Columns: [type, duration, length]
# Index: []

# %%
# Verificar la distribución de tipos
print("=== DISTRIBUCIÓN DE TIPOS ===")
print("Conteo por tipo:")
print(usage['type'].value_counts())
print(f"\nTotal de registros: {len(usage)}")
# Out:
# === DISTRIBUCIÓN DE TIPOS ===
# Conteo por tipo:
# text    22092
# call    17908
# Name: type, dtype: int64
#
# Total de registros: 40000

# %%
# Buscar ejemplos de messages
print("\n=== BUSCANDO MESSAGES ===")
messages_sample = usage[usage['type'] == 'message'].head()
print("Messages encontrados:")
print(messages_sample[['type', 'duration', 'length']])
# Out:
# === BUSCANDO MESSAGES ===
# Messages encontrados:
# Empty DataFrame
# Columns: [type, duration, length]
# Index: []

# %%
# Verificar si hay otros valores en la columna type
print("\n=== VALORES ÚNICOS EN TYPE ===")
print("Valores únicos:", usage['type'].unique())
# Out:
# === VALORES ÚNICOS EN TYPE ===
# Valores únicos: ['call' 'text']

# %%
print("=== EJEMPLOS CORREGIDOS ===")
print("Calls (primeros 5):")
print(usage[usage['type'] == 'call'][['type', 'duration', 'length']].head())
print("\nTexts (primeros 5):")
print(usage[usage['type'] == 'text'][['type', 'duration', 'length']].head())
# Out:
# === EJEMPLOS CORREGIDOS ===
# Calls (primeros 5):
#    type  duration  length
# 0  call      0.09     NaN
# 3  call      1.53     NaN
# 4  call      4.84     NaN
# 5  call      4.68     NaN
# 6  call      3.27     NaN
#
# Texts (primeros 5):
#     type  duration  length
# 1   text       NaN    39.0
# 2   text       NaN    36.0
# 8   text       NaN    44.0
# 9   text       NaN    70.0
# 11  text       NaN    31.0

# %%
# Ahora sí, validemos la consistencia lógica correcta
print("\n=== VALIDACIÓN DE CONSISTENCIA LÓGICA ===")
consistency_check = usage.groupby('type')[['duration', 'length']].apply(lambda x: x.isnull().mean())
print("Porcentaje de nulos por tipo:")
print(consistency_check)
# Out:
# === VALIDACIÓN DE CONSISTENCIA LÓGICA ===
# Porcentaje de nulos por tipo:
#       duration   length
# type
# call  0.000000  0.99933
# text  0.999276  0.00000

# %% [markdown]
# ### 3.2 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Decidir qué hacer con los valores nulos según su proporción y relevancia.
#
# **Instrucciones:**
# - Verifica si los nulos en `duration` y `length` son **MAR**(Missing At Random) revisando si dependen de la columna `type`.
#   Si confirmas que son MAR, **déjalos como nulos** y justifica la decisión.

# %%
# Proporción de nulos en duration por type
mar_duration = (
    usage.assign(duration_null=usage['duration'].isna())
         .groupby('type')['duration_null']
         .mean()
         .sort_values(ascending=False)
)

mar_duration
# Out:
# type
# text    0.999276
# call    0.000000
# Name: duration_null, dtype: float64

# %%
# Proporción de nulos en length por type
mar_length = (
    usage.assign(length_null=usage['length'].isna())
      .groupby('type')['length_null']
      .mean()
      .sort_values(ascending=False)
)

mar_length
# Out:
# type
# call    0.99933
# text    0.00000
# Name: length_null, dtype: float64

# %% [markdown]
# Se ha verificado que los valores nulos en las columnas duration y length no son aleatorios, sino que dependen directamente de la columna type (comportamiento MAR - Missing At Random).
#
# La columna duration es nula casi exclusivamente cuando el tipo de comunicación es "text", ya que los mensajes de texto no tienen una duración en tiempo.
#
# La columna length es nula casi exclusivamente cuando el tipo de comunicación es "call", ya que las llamadas de voz no tienen una longitud de caracteres.
#
# Decisión: Se mantienen los valores como nulos. No se deben imputar (rellenar con promedios o ceros) porque estos nulos representan una ausencia estructural de información: un mensaje de texto no puede tener duración de llamada y viceversa. Rellenarlos introduciría ruido y datos falsos en el análisis.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo con los reemplazos de los valores atípicos de `age` y `city` del datset `users`. Igualmente la verificación de los MAR está correcta, como mencionas, tiene sentido que las proporciones varien segun el tipo ya que las llamadas no tienen un `lenght` y los mensajes no tienen `duration`.
#
# Ten mucho cuidado con volver a traer el dataset desde el archivo original, porque esto borra los procesos realizados y daña el trabajo.

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Summary statistics de uso por usuario
#
#
# ### 4.1 Agrupación por comportamiento de uso
#
# 🎯**Objetivo**: Resumir las variables clave de la tabla `usage` **por usuario**, creando métricas que representen su comportamiento real de uso histórico.
#
# **Instrucciones:**:
# 1. Construye una tabla agregada de `usage` por `user_id` que incluya:
# - número total de mensajes
# - número total de llamadas
# - total de minutos de llamadas
#
# 2. Renombra las columnas para que tengan nombres claros:
# - `cant_mensajes`
# - `cant_llamadas`
# - `cant_minutos_llamada`
# 3. Combina esta tabla con `users`.

# %%
# Columnas auxiliares
usage["is_text"] = (usage["type"] == "text").astype(int)   # total de mensajes
usage["is_call"] = (usage["type"] == "call").astype(int)   # total de llamadas
usage_agg = (
    usage
    .groupby("user_id")
    .agg(
        cant_mensajes=("is_text", "sum"),
        cant_llamadas=("is_call", "sum"),
        cant_minutos_llamada=("duration", "sum")
    )
    .reset_index()
)

# %%
usage_agg.head(3)
# Out:
#    user_id  cant_mensajes  cant_llamadas  cant_minutos_llamada
# 0    10000              7              3                 23.70
# 1    10001              5             10                 33.18
# 2    10002              5              2                 10.74

# %%
user_profile = users_latam.merge(
    usage_agg,
    on="user_id",
    how="left"
)

# %%
user_profile.head(5)
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0         ? 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  is_churned  cant_mensajes  cant_llamadas  \
# 0   Basico        NaN       False            7.0            3.0
# 1   Basico        NaN       False            5.0           10.0
# 2   Basico        NaN       False            5.0            2.0
# 3  Premium        NaN       False           11.0            3.0
# 4   Basico        NaN       False            4.0            3.0
#
#    cant_minutos_llamada
# 0                 23.70
# 1                 33.18
# 2                 10.74
# ...

# %% [markdown]
# ### 4.2 4.2 Resumen estadístico por usuario durante el 2024
#
# 🎯 **Objetivo:** Analizar las columnas numéricas y categóricas de los usuarios, para identificar rangos, valores extremos y distribución de los datos antes de continuar con el análisis.
#
# **Instrucciones:**
# 1. Para las columnas **numéricas** relevantes, obtén un resumen estadístico (media, mediana, mínimo, máximo, etc.).
# 2. Para la columna **categórica** `plan`, revisa la distribución en **porcentajes** de cada categoría.

# %%
users_latam.columns
# Out:
# Index(['user_id', 'first_name', 'last_name', 'age', 'city', 'reg_date', 'plan',
#        'churn_date', 'is_churned'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# La celda anterior es lo que te menciono que debe borrarse para que los datasets no vuelvan a resetearse y perder todo el trabajo.

# %%
# Verificar tipos de datos
print("Tipos de datos en users_latam:")
print(users_latam.dtypes)
print("\n" + "="*50 + "\n")

# Identificar columnas numéricas
columnas_numericas = users_latam.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Columnas numéricas encontradas:")
for col in columnas_numericas:
    print(f"- {col}")
# Out:
# Tipos de datos en users_latam:
# user_id                int64
# first_name            object
# last_name             object
# age                  float64
# city                  object
# reg_date      datetime64[ns]
# plan                  object
# churn_date            object
# is_churned              bool
# dtype: object
#
# ...
#
# Columnas numéricas encontradas:
# - user_id
# - age

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# De nuevo te comento, si haces este paso donde recargas de nuevo todos los datasets, se borra todo el proceso que llevas haciendo.

# %%
# Verificar tipos de datos en usage
print("Tipos de datos en usage:")
print(usage.dtypes)
print("\n" + "="*50 + "\n")

# Identificar columnas numéricas en usage
columnas_numericas_usage = usage.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Columnas numéricas encontradas en usage:")
for col in columnas_numericas_usage:
    print(f"- {col}")

print("\n" + "="*50 + "\n")

# También veamos las primeras filas para entender mejor los datos
print("Primeras 3 filas de usage:")
print(usage.head(3))
# Out:
# Tipos de datos en usage:
# id                   int64
# user_id              int64
# type                object
# date        datetime64[ns]
# duration           float64
# length             float64
# is_text              int64
# is_call              int64
# dtype: object
#
# ...
#
# Columnas numéricas encontradas en usage:
# - id
# - user_id
# - duration
# - length
# - is_text
# - is_call
#
# ...
#
# Primeras 3 filas de usage:
#    id  user_id  type                          date  duration  length  is_text  \
# 0   1    10332  call 2024-01-01 00:00:00.000000000      0.09     NaN        0
# 1   2    11458  text 2024-01-01 00:06:30.969774244       NaN    39.0        1
# 2   3    11777  text 2024-01-01 00:13:01.939548488       NaN    36.0        1
#
#    is_call
# 0        1
# 1        0
# 2        0

# %%
# Ver qué tipos de uso hay
print("Tipos de uso disponibles:")
print(usage['type'].value_counts())
# Out:
# Tipos de uso disponibles:
# text    22092
# call    17908
# Name: type, dtype: int64

# %%
# Ver una muestra de los datos
print("Muestra de datos de usage:")
print(usage.head())
# Out:
# Muestra de datos de usage:
#    id  user_id  type                          date  duration  length  is_text  \
# 0   1    10332  call 2024-01-01 00:00:00.000000000      0.09     NaN        0
# 1   2    11458  text 2024-01-01 00:06:30.969774244       NaN    39.0        1
# 2   3    11777  text 2024-01-01 00:13:01.939548488       NaN    36.0        1
# 3   4    10682  call 2024-01-01 00:19:32.909322733      1.53     NaN        0
# 4   5    12742  call 2024-01-01 00:26:03.879096977      4.84     NaN        0
#
#    is_call
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1

# %%
# Crear el resumen por usuario
user_profile = usage.groupby('user_id').agg({
    'type': 'count',  # Total de registros por usuario
    'duration': 'sum',  # Total minutos de llamadas
    'length': 'count'   # Total de mensajes
}).reset_index()

# Renombrar columnas para que coincidan con tu código original
user_profile.columns = ['user_id', 'total_registros', 'cant_minutos_llamada', 'cant_mensajes']

# %%
# Crear métricas más precisas
user_profile = usage.groupby('user_id').agg({
    'id': 'count',  # Total de actividades
    'duration': 'sum'  # Total minutos
}).reset_index()

# Contar llamadas por usuario
cant_llamadas = usage[usage['type'] == 'call'].groupby('user_id').size()

# Contar mensajes por usuario  
cant_mensajes = usage[usage['type'] == 'text'].groupby('user_id').size()

# Combinar todo
user_profile['cant_llamadas'] = user_profile['user_id'].map(cant_llamadas).fillna(0)
user_profile['cant_mensajes'] = user_profile['user_id'].map(cant_mensajes).fillna(0)
user_profile['cant_minutos_llamada'] = user_profile['duration'].fillna(0)

# %%
# Seleccionar columnas numéricas relevantes
cols_numericas = [
    "cant_mensajes",
    "cant_llamadas",
    "cant_minutos_llamada"
]

# Resumen estadístico
user_profile[cols_numericas].describe().T
# Out:
#                        count       mean        std  min    25%    50%     75%  \
# cant_mensajes         3999.0   5.524381   2.358416  0.0   4.00   5.00   7.000
# cant_llamadas         3999.0   4.478120   2.144238  0.0   3.00   4.00   6.000
# cant_minutos_llamada  3999.0  23.317054  18.168095  0.0  11.12  19.78  31.415
#
#                          max
# cant_mensajes          17.00
# cant_llamadas          15.00
# cant_minutos_llamada  155.69

# %%
# Ver las primeras filas del perfil de usuarios
print("Primeras filas del perfil de usuarios:")
print(user_profile.head())
# Out:
# Primeras filas del perfil de usuarios:
#    user_id  id  duration  cant_llamadas  cant_mensajes  cant_minutos_llamada
# 0    10000  10     23.70            3.0            7.0                 23.70
# 1    10001  15     33.18           10.0            5.0                 33.18
# 2    10002   7     10.74            2.0            5.0                 10.74
# 3    10003  14      8.99            3.0           11.0                  8.99
# 4    10004   7      8.01            3.0            4.0                  8.01

# %%
# Ver información general del DataFrame
print("Información del DataFrame:")
print(user_profile.info())
# Out:
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               3999 non-null   int64
#  1   id                    3999 non-null   int64
#  2   duration              3999 non-null   float64
#  3   cant_llamadas         3999 non-null   float64
#  4   cant_mensajes         3999 non-null   float64
#  5   cant_minutos_llamada  3999 non-null   float64
# dtypes: float64(4), int64(2)
# memory usage: 187.6 KB
# None

# %%
print("Columnas en user_profile:")
print(user_profile.columns.tolist())
# Out:
# Columnas en user_profile:
# ['user_id', 'id', 'duration', 'cant_llamadas', 'cant_mensajes', 'cant_minutos_llamada']

# %%
print("Primeras 5 filas de user_profile:")
print(user_profile.head())
# Out:
# Primeras 5 filas de user_profile:
#    user_id  id  duration  cant_llamadas  cant_mensajes  cant_minutos_llamada
# 0    10000  10     23.70            3.0            7.0                 23.70
# 1    10001  15     33.18           10.0            5.0                 33.18
# 2    10002   7     10.74            2.0            5.0                 10.74
# 3    10003  14      8.99            3.0           11.0                  8.99
# 4    10004   7      8.01            3.0            4.0                  8.01

# %%
print("Columnas en users:")
print(users_latam.columns.tolist())
print("\nPrimeras filas de users:")
print(users_latam.head())
# Out:
# Columnas en users:
# ['user_id', 'first_name', 'last_name', 'age', 'city', 'reg_date', 'plan', 'churn_date', 'is_churned']
#
# Primeras filas de users:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0         ? 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  is_churned
# 0   Basico        NaN       False
# 1   Basico        NaN       False
# 2   Basico        NaN       False
# 3  Premium        NaN       False
# 4   Basico        NaN       False

# %%
dataset_final = users_latam.merge(
    user_profile,
    on="user_id",


    how="left"


)

# %%
print("Forma del dataset final:", dataset_final.shape)
print("\nPrimeras filas:")
print(dataset_final.head())
print("\nValores nulos por columna:")
print(dataset_final.isnull().sum())
# Out:
# Forma del dataset final: (4000, 14)
#
# Primeras filas:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0         ? 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  is_churned    id  duration  cant_llamadas  \
# 0   Basico        NaN       False  10.0     23.70            3.0
# 1   Basico        NaN       False  15.0     33.18           10.0
# 2   Basico        NaN       False   7.0     10.74            2.0
# 3  Premium        NaN       False  14.0      8.99            3.0
# 4   Basico        NaN       False   7.0      8.01            3.0
#
#    cant_mensajes  cant_minutos_llamada
# ...

# %%
cols_uso = [
    "cant_mensajes",
    "cant_llamadas",
    "cant_minutos_llamada"
]

dataset_final[cols_uso] = dataset_final[cols_uso].fillna(0)

# %%
# Crear el dataset final
dataset_final = users_latam.merge(
    user_profile,
    on="user_id",
    how="left"
)

# Mostrar información básica
print("¿Se creó dataset_final?", 'dataset_final' in locals())
print("Forma del dataset:", dataset_final.shape)
# Out:
# ¿Se creó dataset_final? True
# Forma del dataset: (4000, 14)

# %%
# Ver las primeras filas
print("Primeras 5 filas:")
print(dataset_final.head())
# Out:
# Primeras 5 filas:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0         ? 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  is_churned    id  duration  cant_llamadas  \
# 0   Basico        NaN       False  10.0     23.70            3.0
# 1   Basico        NaN       False  15.0     33.18           10.0
# 2   Basico        NaN       False   7.0     10.74            2.0
# 3  Premium        NaN       False  14.0      8.99            3.0
# 4   Basico        NaN       False   7.0      8.01            3.0
#
#    cant_mensajes  cant_minutos_llamada
# 0            7.0                 23.70
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Genial! La creación de la tabla auxiliar con el conteo de llamadas y mensajes por usuario está super bien, muy buen uso del filtrado, el agrupamiento con `groupby` y el `merge`.
#
# El resumen estadístico también está super bien.

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Visualización de distribuciones (uso y clientes) y outliers
#
#
# ### 5.1 Visualización de Distribuciones
#
# 🎯 **Objetivo:**
# Entender visualmente cómo se comportan las variables clave tanto de **uso** como de **clientes**, observar si existen diferencias según el tipo de plan, y analizar la **forma de la distribución**.
#
# **Instrucciones:**
# Graficar **histogramas** para las siguientes columnas:
# - `age` (edad de los usuarios)
# - `cant_mensajes`
# - `cant_llamadas`
# - `total_minutos_llamada`
#
# Después de cada gráfico, escribe un **insight** respecto al plan y la variable, por ejemplo:
# - "Dentro del plan Premium, hay mayor proporción de..."
# - "Los usuarios Básico tienden a hacer ... llamadas y enviar ... mensajes."  o "No existe algún patrón."
# - ¿Qué tipo de distribución tiene ? (simétrica, sesgada a la derecha o a la izquierda)
#
# **Hint**
# Para cada histograma,
# - Usa `hue='plan'` para ver cómo varían las distribuciones según el plan (Básico o Premium).
# - Usa `palette=['skyblue','green']`
# - Agrega título y etiquetas

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.histplot(
    data=dataset_final,
    x="age",
    hue="plan",
    bins=20,
    palette=["skyblue", "green"],
    kde=True
)
plt.title("Distribución de edad por tipo de plan")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# 1. El Plan Básico es mucho más popular (Volumen)
# Lo primero que salta a la vista es la diferencia de volumen. Las barras azules (Básico) son consistentemente más altas que las verdes (Premium) en absolutamente todos los rangos de edad.
#
# Conclusión: La base de usuarios del plan "Básico" es significativamente mayor a la del "Premium", sin importar la edad.
#
# 2. La edad NO determina la elección del plan
# Este es el insight más valioso para un análisis de negocio. Las líneas de tendencia (las curvas suaves encima de las barras) tienen una forma casi idéntica entre sí.
#
# Si los jóvenes prefirieran el plan Básico y los mayores el Premium, veríamos la curva azul alta a la izquierda y la verde alta a la derecha.
#
# Al ser paralelas, significa que la proporción de gente que elige Premium vs. Básico es prácticamente la misma si tienes 20 años o si tienes 70.
#
# Conclusión: La edad no es una variable que prediga qué plan va a elegir el cliente.
#
# 3. Distribución Demográfica Uniforme
# A diferencia de muchos servicios tecnológicos que tienen picos en usuarios jóvenes (20-30 años), tu distribución es bastante plana o uniforme.
#
# Tienes una cantidad muy saludable de usuarios en todos los rangos, desde los 18 hasta los 80 años.
#
# No hay una concentración masiva en un solo grupo generacional.
#
# 4. Ligeros picos en los extremos
# Aunque es uniforme, se notan ligeras concentraciones:
#
# Un pico notable en los usuarios más jóvenes (18-20 años) en el plan Básico.
#
# Curiosamente, un repunte en usuarios mayores (70-80 años), especialmente visible en el plan Básico también.

# %%
plt.figure(figsize=(8,5))
sns.histplot(
    data=dataset_final,
    x="cant_mensajes",
    hue="plan",
    bins=30,
    palette=["skyblue", "green"]
)
plt.title("Distribución de mensajes enviados por plan")
plt.xlabel("Cantidad de mensajes")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# Insights clave
#
# 1️⃣ El plan Básico concentra más usuarios
#
# Las barras del Básico son más altas en casi todos los rangos.
#
# Esto sugiere que hay más usuarios en el plan Básico o que es el plan dominante en la base.
#
# 2️⃣ Ambos planes tienen un comportamiento parecido
#
# Las dos distribuciones tienen forma similar (tipo campana).
#
# El uso típico de mensajes es moderado, no extremo, en ambos planes.
#
# 3️⃣ El rango más común está entre 4 y 7 mensajes
#
# El pico principal para ambos planes está alrededor de:
#
# 5–6 mensajes
#
# Esto indica el uso promedio esperado de un usuario estándar.
#
# 4️⃣ Premium tiene ligeramente más usuarios en rangos altos
#
# A partir de 8–10 mensajes, el plan Premium mantiene presencia más constante.
#
# Insight importante:
# 👉 Los usuarios Premium tienden a usar más mensajes, aunque no de forma radical.
#
# 5️⃣ Uso extremo es raro
#
# Muy pocos usuarios superan los 12–15 mensajes.
#
# Esto sugiere:
#
# Los límites actuales probablemente no están siendo presionados
#
# O el producto no incentiva consumo intensivo de mensajes

# %%
plt.figure(figsize=(8,5))
sns.histplot(
    data=dataset_final,
    x="cant_llamadas",
    hue="plan",
    bins=30,
    palette=["skyblue", "green"]
)
plt.title("Distribución de llamadas realizadas por plan")
plt.xlabel("Cantidad de llamadas")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# Insights principales
#
# 1️⃣ El plan Básico tiene mayor volumen total
#
# Las barras del Básico son más altas en casi todos los rangos.
#
# Indica que:
#
# Hay más usuarios Básicos, o
#
# El plan Básico concentra a la mayoría de los clientes activos.
#
# 2️⃣ El uso típico está entre 3 y 6 llamadas
#
# El pico de ambas distribuciones se encuentra alrededor de:
#
# 4–5 llamadas
#
# Este es el comportamiento promedio del usuario estándar.
#
# 3️⃣ Premium muestra un uso ligeramente más intensivo
#
# A partir de 6–9 llamadas, el plan Premium mantiene más presencia relativa.
#
# Insight clave:
# 👉 Los usuarios Premium tienden a hacer más llamadas, aunque la diferencia no es extrema.
#
# 4️⃣ Las llamadas muy altas son poco frecuentes
#
# Muy pocos usuarios superan las 10–12 llamadas.
#
# No se observan colas largas → uso controlado del servicio.
#
# 5️⃣ Distribuciones muy similares
#
# Ambas curvas tienen forma parecida.
#
# Esto sugiere que:
#
# El tipo de usuario no cambia drásticamente entre planes
#
# La diferencia está más en el volumen permitido que en el comportamiento base

# %%
plt.figure(figsize=(8,5))
sns.histplot(
    data=dataset_final,
    x="cant_minutos_llamada",
    hue="plan",
    bins=30,
    palette=["skyblue", "green"]
)
plt.title("Distribución de minutos de llamada por plan")
plt.xlabel("Minutos de llamada")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# Insights principales
#
# 1️⃣ El consumo típico es bajo–medio
#
# La mayor concentración está entre 5 y 30 minutos.
#
# El pico principal parece alrededor de 15–20 minutos.
#
# Esto indica que la mayoría de los usuarios no usa intensivamente las llamadas.
#
# 2️⃣ El plan Básico concentra más usuarios
#
# Las barras del Básico son más altas en casi todo el rango.
#
# Refleja que:
#
# Hay más usuarios en el plan Básico, o
#
# Es el plan más popular del portafolio.
#
# 3️⃣ Premium muestra colas más largas
#
# A partir de 40–60 minutos, el plan Premium mantiene mayor presencia relativa.
#
# Insight clave:
# 👉 Los usuarios Premium tienden a hablar más tiempo cuando lo hacen.
#
# 4️⃣ Uso extremo es raro, pero existe
#
# Hay pocos usuarios que superan los 80–100 minutos, llegando hasta ~150.
#
# Probablemente:
#
# Usuarios con necesidades específicas
#
# O llamadas ocasionales muy largas
#
# 5️⃣ Distribución sesgada a la derecha
#
# Ambas distribuciones tienen cola larga.
#
# La media seguramente es mayor que la mediana, importante para análisis de costos.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Has reconocido muy bien las tendencias de cada una de las variables, señalando los sesgos a la derecha de estas y las diferencias principales entre ambos planes. Sin embargo, por el hecho que te mencioné de recargar los datasets continuamente, borraste las correcciones de los datos de edad, y por ello aparece un valor anomalo en -999.

# %% [markdown]
# ### 5.2 Identificación de Outliers
#
# 🎯 **Objetivo:**
# Detectar valores extremos en las variables clave de **uso** y **clientes** que podrían afectar el análisis, y decidir si requieren limpieza o revisión adicional.
#
# **Instrucciones:**
# - Usa **boxplots** para identificar visualmente outliers en las siguientes columnas:
#   - `age`
#   - `cant_mensajes`
#   - `cant_llamadas`
#   - `total_minutos_llamada`
# - Crea un **for** para generar los 4 boxplots automáticamente.
# <br>
#
# - Después de crear los gráfico, responde si **existen o no outliers** en las variables.
# - Si hay outliers, crea otro bucle para calcular los límites de esas columnas usando el **método IQR** y decide qué hacer con ellos.
#   - Si solamente hay outliers de un solo lado, no es necesario calcular ambos límites.
#
# **Hint:**
# - Dentro del bucle, usa `plt.title(f'Boxplot: {col}')` para que el título cambie acorde a la columna.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

columnas_numericas = [
    "age",
    "cant_mensajes",
    "cant_llamadas",
    "cant_minutos_llamada"
]

for col in columnas_numericas:
    plt.figure(figsize=(6,4))
    sns.boxplot(
        data=dataset_final,
        y=col
    )
    plt.title(f"Boxplot: {col}")
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# age (Edad):
#
# ¿Hay Outliers? NO.
#
# Análisis: El boxplot es perfectamente simétrico y no muestra ningún punto (rombo) por fuera de los "bigotes" (las líneas superior e inferior). Esto confirma lo que vimos en el histograma anterior: la distribución de edades es uniforme y acotada entre ~18 y 80 años. No hay nada extraño aquí.
#
# cant_mensajes (Cantidad de Mensajes):
#
# ¿Hay Outliers? SÍ.
#
# Análisis: Se observan varios puntos negros por encima del límite superior (aproximadamente arriba de 11 mensajes). Estos son usuarios que envían más mensajes de lo "normal", llegando hasta casi 18 mensajes.
#
# cant_llamadas (Cantidad de Llamadas):
#
# ¿Hay Outliers? SÍ.
#
# Análisis: Similar a los mensajes, hay puntos aislados por encima del bigote superior (que termina en 10). Hay usuarios con 11, 12, 13 y hasta 15 llamadas.
#
# cant_minutos_llamada (Minutos Totales):
#
# ¿Hay Outliers? SÍ (Muchos).
#
# Análisis: Este es el caso más extremo. El bloque de puntos negros es muy denso por encima de los 60 minutos. Hay una gran cantidad de usuarios que hablan entre 60 y 160 minutos.
#
# Nota: En telecomunicaciones, esto es común. La mayoría habla poco, pero los que hablan mucho, hablan muchísimo.

# %%
columnas_limites = [
    "cant_mensajes",
    "cant_llamadas",
    "cant_minutos_llamada"
]

limites_iqr = {}

for col in columnas_limites:
    Q1 = dataset_final[col].quantile(0.25)
    Q3 = dataset_final[col].quantile(0.75)
    IQR = Q3 - Q1
    limite_superior = Q3 + 1.5 * IQR

    limites_iqr[col] = limite_superior

# %%
dataset_final[columnas_limites].describe()
# Out:
#        cant_mensajes  cant_llamadas  cant_minutos_llamada
# count    3999.000000    3999.000000           3999.000000
# mean        5.524381       4.478120             23.317054
# std         2.358416       2.144238             18.168095
# min         0.000000       0.000000              0.000000
# 25%         4.000000       3.000000             11.120000
# 50%         5.000000       4.000000             19.780000
# 75%         7.000000       6.000000             31.415000
# max        17.000000      15.000000            155.690000

# %% [markdown]
# Visión General
# Volumen de datos: La fila count muestra 3999 registros para las tres variables, lo que indica que no hay valores nulos en esta selección específica de datos.
#
# Variables analizadas: Cantidad de mensajes, cantidad de llamadas y el total de minutos consumidos.
#
# 2. Análisis por Variable
# A. cant_mensajes (Mensajería)
#
# Comportamiento estable: La media (5.52) y la mediana (5.0) son casi idénticas. Esto significa que la distribución es bastante simétrica; la mayoría de los usuarios envían alrededor de 5 mensajes.
#
# Poca dispersión: La desviación estándar (2.35) es baja. El 75% de los usuarios (Q3) envía 7 mensajes o menos.
#
# Tope bajo: El valor máximo es 17, lo cual no es exageradamente alto comparado con el promedio. No hay usuarios enviando miles de mensajes aquí.
#
# B. cant_llamadas (Frecuencia de llamadas)
#
# Uso bajo: El promedio es de ~4.5 llamadas. La mitad de los registros (mediana) tienen 4 llamadas o menos.
#
# Simetría: Al igual que en los mensajes, la media y la mediana están muy cerca, indicando una distribución normal sin sesgos fuertes.
#
# C. cant_minutos_llamada (Duración/Consumo - ¡El dato crítico!)
#
# Alta Variabilidad: Aquí es donde cambia la historia. La desviación estándar (18.16) es casi tan grande como la mediana (19.78). Esto indica que el comportamiento de los usuarios es muy heterogéneo: unos hablan muy poco y otros muchísimo.
#
# Sesgo a la derecha (Right Skew): La media (23.31) es notablemente mayor que la mediana (19.78). Esto ocurre porque los usuarios que hablan mucho (los valores altos) están "jalando" el promedio hacia arriba.
#
# Confirmación de Outliers: Fíjate en el salto entre el 75% y el Máximo:
#
# El 75% de los usuarios habla 31.4 minutos o menos.
#
# Pero el valor máximo es 155.69 minutos.
#
# Este máximo es 5 veces mayor que el tercer cuartil. Esto confirma numéricamente lo que vimos en los gráficos: hay un grupo de "Heavy Users" que se sale completamente de la norma.
#
# 3. Conclusión de Negocio
# El análisis de esta tabla nos dice que:
#
# El tráfico de mensajes y cantidad de llamadas es predecible y homogéneo. No hay grandes sorpresas ahí.
#
# El consumo de minutos es la variable clave. Es la que tiene mayor dispersión y valores extremos. Para tu negocio de telecomunicaciones, esto sugiere que el riesgo (o la oportunidad de ingresos por excedentes) está en la duración de las llamadas, no en cuántas veces llaman ni en cuántos mensajes mandan.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo con los boxplots y el calculo de intercuartiles. Como mencionas, los outliers que se presentan no son anomalos y se pueden conservar.

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Segmentación de Clientes
#
# ### 6.1 Segmentación de Clientes Por Uso
#
# 🎯 **Objetivo:** Clasificar a cada usuario en un grupo de uso (Bajo uso, Uso medio, Alto uso) basándose en la cantidad de llamadas y mensajes registrados.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_uso` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones de llamadas y mensajes y asigna:
#   - `'Bajo uso'` cuando llamadas < 5 y mensajes < 5
#   - `'Uso medio'` cuando llamadas < 10 y mensajes < 10
#   - `'Alto uso'` para el resto de casos

# %%
# Crear columna grupo_uso
user_profile["grupo_uso"] = "Alto uso"

user_profile.loc[
    (user_profile["cant_llamadas"] < 5) & (user_profile["cant_mensajes"] < 5),
    "grupo_uso"
] = "Bajo uso"

user_profile.loc[
    (user_profile["cant_llamadas"] < 10) & (user_profile["cant_mensajes"] < 10) &
    (user_profile["grupo_uso"] != "Bajo uso"),
    "grupo_uso"
] = "Uso medio"

# %%
user_profile.head()
# Out:
#    user_id  id  duration  cant_llamadas  cant_mensajes  cant_minutos_llamada  \
# 0    10000  10     23.70            3.0            7.0                 23.70
# 1    10001  15     33.18           10.0            5.0                 33.18
# 2    10002   7     10.74            2.0            5.0                 10.74
# 3    10003  14      8.99            3.0           11.0                  8.99
# 4    10004   7      8.01            3.0            4.0                  8.01
#
#    grupo_uso
# 0  Uso medio
# 1   Alto uso
# 2  Uso medio
# 3   Alto uso
# 4   Bajo uso

# %% [markdown]
# ### 6.2 Segmentación de Clientes Por Edad
#
# 🎯 **Objetivo:**: Clasificar a cada usuario en un grupo por **edad**.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_edad` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones y asigna:
#   - `'Joven'` cuando age < 30
#   - `'Adulto'` cuando age < 60
#   - `'Adulto Mayor'` para el resto de casos

# %%
print("Columnas en user_profile:")
print(user_profile.columns.tolist())
# Out:
# Columnas en user_profile:
# ['user_id', 'id', 'duration', 'cant_llamadas', 'cant_mensajes', 'cant_minutos_llamada', 'grupo_uso']

# %%
print("\nPrimeras 5 filas:")
print(user_profile.head())
# Out:
# Primeras 5 filas:
#    user_id  id  duration  cant_llamadas  cant_mensajes  cant_minutos_llamada  \
# 0    10000  10     23.70            3.0            7.0                 23.70
# 1    10001  15     33.18           10.0            5.0                 33.18
# 2    10002   7     10.74            2.0            5.0                 10.74
# 3    10003  14      8.99            3.0           11.0                  8.99
# 4    10004   7      8.01            3.0            4.0                  8.01
#
#    grupo_uso
# 0  Uso medio
# 1   Alto uso
# 2  Uso medio
# 3   Alto uso
# 4   Bajo uso

# %%
# Verificar si tienes dataset_final
if 'dataset_final' in locals():
    print("Columnas en dataset_final:")
    print(dataset_final.columns.tolist())
    print("\nPrimeras filas:")
    print(dataset_final.head())
# Out:
# Columnas en dataset_final:
# ['user_id', 'first_name', 'last_name', 'age', 'city', 'reg_date', 'plan', 'churn_date', 'id', 'duration', 'cant_llamadas', 'cant_mensajes', 'cant_minutos_llamada']
#
# Primeras filas:
#    user_id first_name last_name  age      city                       reg_date  \
# 0    10000     Carlos    Garcia   38  Medellín  2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres   53         ?  2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez   57      CDMX  2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez   69    Bogotá  2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres   63       GDL  2022-01-02 02:17:11.657914478
#
#       plan churn_date    id  duration  cant_llamadas  cant_mensajes  \
# 0   Basico        NaN  10.0     23.70            3.0            7.0
# 1   Basico        NaN  15.0     33.18           10.0            5.0
# 2   Basico        NaN   7.0     10.74            2.0            5.0
# ...

# %%
# Agregar la columna age desde dataset_final
user_profile = user_profile.merge(
    dataset_final[['user_id', 'age']], 
    on='user_id', 
    how='left'
)

# %%
# Verificar las columnas actuales
print("Columnas en user_profile:")
print(user_profile.columns.tolist())
# Out:
# Columnas en user_profile:
# ['user_id', 'id', 'duration', 'cant_llamadas', 'cant_mensajes', 'cant_minutos_llamada', 'grupo_uso', 'age']

# %%
# Crear columna grupo_edad (resetear primero)
user_profile["grupo_edad"] = "Adulto Mayor"

user_profile.loc[
    user_profile["age"] < 30,
    "grupo_edad"
] = "Joven"

user_profile.loc[
    (user_profile["age"] < 60) & (user_profile["grupo_edad"] != "Joven"),
    "grupo_edad"
] = "Adulto"

# %%
# verificar cambios
user_profile.head()
# Out:
#    user_id  id  duration  cant_llamadas  cant_mensajes  cant_minutos_llamada  \
# 0    10000  10     23.70            3.0            7.0                 23.70
# 1    10001  15     33.18           10.0            5.0                 33.18
# 2    10002   7     10.74            2.0            5.0                 10.74
# 3    10003  14      8.99            3.0           11.0                  8.99
# 4    10004   7      8.01            3.0            4.0                  8.01
#
#    grupo_uso   age    grupo_edad
# 0  Uso medio  38.0        Adulto
# 1   Alto uso  53.0        Adulto
# 2  Uso medio  57.0        Adulto
# 3   Alto uso  69.0  Adulto Mayor
# 4   Bajo uso  63.0  Adulto Mayor

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Aqui el error que se viene propagando con la columna `age` causa errores en las celdas. Revisa desde los primeros pasos hasta aquí y recuerda eliminar todos los pasos en donde se haya vuelto a importar los datasets.

# %% [markdown]
# ### 6.3 Visualización de la Segmentación de Clientes
#
# 🎯 **Objetivo:** Visualizar la distribución de los usuarios según los grupos creados: **grupo_uso** y **grupo_edad**.
#
# **Instrucciones:**
# - Crea dos gráficos para las variables categóricas `grupo_uso` y `grupo_edad`.
# - Agrega título y etiquetas a los ejes en cada gráfico.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
sns.countplot(
    data=user_profile,
    x="grupo_uso",
    palette=["skyblue", "green", "orange"]
)

plt.title("Distribución de usuarios por grupo de uso")
plt.xlabel("Grupo de uso")
plt.ylabel("Número de usuarios")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(
    data=user_profile,
    x="grupo_edad",
    palette=["skyblue", "green", "orange"]
)

plt.title("Distribución de usuarios por grupo de edad")
plt.xlabel("Grupo de edad")
plt.ylabel("Número de usuarios")
plt.show()

# %% [markdown]
# ---
# ##
# 🧩Paso 7: Insight Ejecutivo para Stakeholders
#
# 🎯 **Objetivo:** Traducir los hallazgos del análisis en conclusiones accionables para el negocio, enfocadas en segmentación, patrones de uso y oportunidades comerciales.
#
# **Preguntas a responder:**
# - ¿Qué problemas tenían originalmemte los datos?¿Qué porcentaje, o cantidad de filas, de esa columna representaban?
#
#
# - ¿Qué segmentos de clientes identificaste y cómo se comportan según su edad y nivel de uso?
# - ¿Qué segmentos parecen más valiosos para ConnectaTel y por qué?
# - ¿Qué patrones de uso extremo (outliers) encontraste y qué implican para el negocio?
#
#
# - ¿Qué recomendaciones harías para mejorar la oferta actual de planes o crear nuevos planes basados en los segmentos y patrones detectados?
#
# ✍️ **Escribe aquí tu análisis ejecutivo:**

# %% [markdown]
# Insights ejecutivos – Proyecto ConnectaTel
# 1️⃣ ¿Qué problemas tenían originalmente los datos y qué impacto tenían?
# Problemas de calidad detectados
#
# a) Edades inválidas
#
# Se encontraron valores como -999 en la columna age
#
# Esto es un valor inválido, probablemente usado para representar datos faltantes
#
# Impacto
#
# Distorsiona métricas clave:
#
# Media de edad artificialmente baja
#
# Desviación estándar exagerada
#
# Cualquier análisis por edad era poco confiable sin limpieza previa
#
# Alcance
#
# Afecta a una minoría de registros, pero con alto impacto estadístico
#
# b) Valores faltantes en métricas de uso
#
# duration (duración de llamadas): ~45% de registros
#
# length (minutos de llamada): ~55% de registros
#
# Impacto
#
# No todos los eventos tienen información completa
#
# Las métricas de promedio no representan al total de usuarios
#
# Obliga a segmentar el análisis solo con datos válidos
#
# c) Outliers extremos
#
# Minutos de llamada de hasta 1490
#
# Duraciones de hasta 120
#
# Impacto
#
# Inflan la media
#
# Indican:
#
# Errores de captura, o
#
# Casos muy específicos de uso intensivo
#
# 2️⃣ ¿Qué segmentos de clientes se identificaron y cómo se comportan?
# Segmentación principal (edad + uso)
# 🧑 Segmento 1: Usuarios adultos de uso moderado (segmento mayoritario)
#
# Edad típica: 32 – 63 años
#
# Uso:
#
# 4–7 mensajes
#
# 3–6 llamadas
#
# 10–30 minutos de llamada
#
# Plan dominante: Básico
#
# 👉 Representan el core del negocio
#
# 📈 Segmento 2: Usuarios intensivos (heavy users)
#
# Edad: generalmente adultos
#
# Uso:
#
# Mensajes y llamadas por encima del percentil 75
#
# Minutos de llamada > 40–60
#
# Plan dominante: Premium
#
# 👉 Aunque son menos, consumen más recursos y pagan más
#
# 🧪 Segmento 3: Usuarios de bajo uso
#
# Uso mínimo o esporádico
#
# Frecuentes valores cercanos a cero
#
# Sensibles al precio
#
# 👉 Riesgo de churn, pero bajo costo operativo
#
# 3️⃣ ¿Qué segmentos parecen más valiosos para ConnectaTel y por qué?
# ⭐ Segmentos más valiosos
# 🥇 Usuarios Premium + uso intensivo
#
# Mayor consumo de mensajes y minutos
#
# Aprovechan los beneficios del plan
#
# Alta probabilidad de retención si el servicio cumple
#
# Valor para el negocio
#
# Mayor ingreso por usuario
#
# Justifican planes de mayor margen
#
# 🥈 Usuarios Básicos cercanos al límite
#
# Uso constante en percentiles altos del plan Básico
#
# No son intensivos aún, pero están cerca
#
# Valor estratégico
#
# Mejor oportunidad de upselling
#
# Bajo costo de adquisición (ya son clientes)
#
# 4️⃣ ¿Qué patrones de uso extremo se encontraron y qué implican?
# Patrones detectados
#
# Muy pocos usuarios con:
#
# 100 minutos
#
# 1000 unidades en métricas de longitud
#
# Distribuciones con cola larga (sesgo a la derecha)
#
# Implicaciones de negocio
#
# El uso extremo:
#
# No es masivo
#
# Está concentrado en pocos usuarios
#
# No representa una amenaza inmediata de costos
#
# Pero sí:
#
# Requiere monitoreo
#
# Puede justificar planes especiales o políticas de fair use
#
# 5️⃣ Recomendaciones estratégicas para planes y oferta comercial
# 🔧 Mejora de planes actuales
#
# Optimizar comunicación del plan Premium
#
# El uso muestra que sí habilita mayor consumo
#
# El valor no siempre es evidente para el usuario
#
# Definir alertas de uso
#
# Para usuarios Básicos cercanos al límite
#
# Activar campañas de upgrade oportunas
#
# 🆕 Nuevos planes sugeridos
#
# Plan intermedio (Mid-tier)
#
# Para usuarios Básicos de uso alto
#
# Precio menor que Premium
#
# Beneficio:
#
# Reduce churn
#
# Incrementa ARPU gradualmente
#
# Plan Heavy User
#
# Para el 5–10% de usuarios con consumo extremo
#
# Incluye:
#
# Minutos ampliados
#
# Precio premium
#
# Controla costos y monetiza mejor
#
# 🎯 Conclusión ejecutiva
#
# La base de clientes de ConnectaTel muestra un comportamiento mayoritariamente moderado, con un grupo reducido de usuarios intensivos que concentran el consumo. Tras corregir problemas de calidad de datos, se identifican claras oportunidades de upselling y diseño de planes intermedios que permiten aumentar ingresos sin elevar significativamente los costos operativos.

# %% [markdown]
# ---
#
# ## 🧩Paso 8 Cargar tu notebook y README a GitHub
#
# 🎯 **Objetivo:**
# Entregar tu análisis de forma **profesional**, **documentada** y **versionada**, asegurando que cualquier persona pueda revisar, ejecutar y entender tu trabajo.
#
#
#
# ### Opción A : Subir archivos desde la interfaz de GitHub (UI)
#
# 1. Descarga este notebook (`File → Download .ipynb`).
# 2. Entra a tu repositorio en GitHub (por ejemplo `telecom-analysis` o `sprint7-final-project`).
# 3. Sube tu notebook **Add file → Upload files**.
#
# ---
#
# ### Opción B : Guardar directo desde Google Colab
#
# 1. Abre tu notebook en Colab.
# 2. Ve a **File → Save a copy in GitHub**.
# 3. Selecciona el repositorio y la carpeta correcta (ej: `notebooks/`).
# 4. Escribe un mensaje de commit claro, por ejemplo:
#     - `feat: add final ConnectaTel analysis`
#     - `agregar version final: Análisis ConnectaTel`
# 5. Verifica en GitHub que el archivo quedó en el lugar correcto y que el historial de commits se mantenga limpio.
#
# ---
#
# Agrega un archivo `README.md` que describa de forma clara:
# - el objetivo del proyecto,
# - los datasets utilizados,
# - las etapas del análisis realizadas,
# - cómo ejecutar el notebook (por ejemplo, abrirlo en Google Colab),
# - una breve guía de reproducción.
# ---

# %% [markdown]
# Link a repositorio público del proyecto: `LINK a tu repo aquí`

# %%
repo_url = "https://github.com/GerardoVazquezR/sprint7-final-project.git"
print(f"Mi repositorio: {repo_url}")
# Out:
# Mi repositorio: https://github.com/GerardoVazquezR/sprint7-final-project.git
